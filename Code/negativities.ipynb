# %%
# Qiskit
from qiskit import IBMQ

# Local modules
from utilities import startup, check_provider
from graphstate import GraphState
from analysis import plot_negativities

provider = startup()
# Out:
# Provider: ibm-q-melbourne

# %%
backend = provider.get_backend('ibmq_lima')
result = backend.jobs()[0].result()

lima = GraphState(backend)
#lima.run_qst(qrem=True)
lima.qst_from_result(result)
fig = plot_negativities(lima)
fig.savefig('output/negativities/lima_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibmq_belem')
result = backend.jobs()[0].result()

belem = GraphState(backend)
#belem.run_qst(qrem=True)
belem.qst_from_result(result)
fig = plot_negativities(belem)
fig.savefig('output/negativities/belem_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibmq_quito')
result = backend.jobs()[0].result()

quito = GraphState(backend)
#quito.run_qst(qrem=True)
quito.qst_from_result(result)
fig = plot_negativities(quito)
fig.savefig('output/negativities/quito_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibmq_santiago')
result = backend.jobs()[0].result()

santiago = GraphState(backend)
#santiago.run_qst(qrem=True)
santiago.qst_from_result(result)
fig = plot_negativities(santiago)
fig.savefig('output/negativities/santiago_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibmq_bogota')
#result = backend.jobs()[0].result()

bogota = GraphState(backend)
bogota.run_qst(qrem=True)
#bogota.qst_from_result(result)
fig = plot_negativities(bogota)
fig.savefig('output/negativities/bogota_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibmq_manila')
result = backend.jobs()[0].result()

manila = GraphState(backend)
#manila.run_qst(qrem=True)
manila.qst_from_result(result)
fig = plot_negativities(manila)
fig.savefig('output/negativities/manila_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibmq_jakarta')
result = backend.jobs()[0].result()

jakarta = GraphState(backend)
#jakarta.run_qst(qrem=True)
jakarta.qst_from_result(result)
fig = plot_negativities(jakarta)
fig.savefig('output/negativities/jakarta_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibm_lagos')
result = backend.jobs()[0].result()

lagos = GraphState(backend)
#lagos.run_qst(qrem=True)
lagos.qst_from_result(result)
fig = plot_negativities(lagos)
fig.savefig('output/negativities/lagos_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibm_perth')
result = backend.jobs()[0].result()

perth = GraphState(backend)
#perth.run_qst(qrem=True)
perth.qst_from_result(result)
fig = plot_negativities(perth)
fig.savefig('output/negativities/perth_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibmq_guadalupe')
result = backend.jobs()[0].result()

guadalupe = GraphState(backend)
#guadalupe.run_qst(qrem=True)
guadalupe.qst_from_result(result)
fig = plot_negativities(guadalupe)
fig.savefig('output/negativities/guadalupe_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibmq_toronto')
result = backend.jobs()[1].result()

toronto = GraphState(backend)
#toronto.run_qst(qrem=True)
toronto.qst_from_result(result)
fig = plot_negativities(toronto)
fig.savefig('output/negativities/toronto_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibm_hanoi')
result = backend.jobs()[0].result()

hanoi = GraphState(backend)
#hanoi.run_qst(qrem=True)
hanoi.qst_from_result(result)
fig = plot_negativities(hanoi)
fig.savefig('output/negativities/hanoi_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibm_auckland')
result = backend.jobs()[0].result()

auckland = GraphState(backend)
#auckland.run_qst(qrem=True)
auckland.qst_from_result(result)
fig = plot_negativities(auckland)
fig.savefig('output/negativities/auckland_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibm_cairo')
result = backend.jobs()[0].result()

cairo = GraphState(backend)
#cairo.run_qst(qrem=True)
cairo.qst_from_result(result)
fig = plot_negativities(cairo)
fig.savefig('output/negativities/cairo_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibmq_mumbai')
result = backend.jobs()[0].result()

mumbai = GraphState(backend)
#mumbai.run_qst(qrem=True)
mumbai.qst_from_result(result)
fig = plot_negativities(mumbai)
fig.savefig('output/negativities/mumbai_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibmq_montreal')
result = backend.jobs()[0].result()

montreal = GraphState(backend)
montreal.qst_from_result(result)
fig = plot_negativities(montreal)
fig.savefig('output/negativities/montreal_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibmq_kolkata')
result = backend.jobs()[0].result()

kolkata = GraphState(backend)
#kolkata.run_qst(qrem=True)
kolkata.qst_from_result(result)
fig = plot_negativities(kolkata)
fig.savefig('output/negativities/kolkata_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibmq_brooklyn')
result = backend.jobs()[0].result()

brook = GraphState(backend)
#brook.run_qst(qrem=True)
brook.qst_from_result(result)
fig = plot_negativities(brook, size=(12, 6))
fig.savefig('output/negativities/brooklyn_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibm_washington')
result = backend.jobs()[0].result()

wash = GraphState(backend)
#brook.run_qst(qrem=True)
wash.qst_from_result(result)
fig = plot_negativities(wash, size=(22, 6))
fig.savefig('output/negativities/washington_negativities.png', dpi=144, bbox_inches='tight')

# %%
backend = provider.get_backend('ibmq_brooklyn')

for i in range(8):
    brook = GraphState(backend)
    brook.run_qst(qrem=True)
